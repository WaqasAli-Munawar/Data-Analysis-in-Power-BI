# %% [markdown]
# ### WE WILL LEARN HOW TO
# * Explore statistical summaries
# * Identify outliers with Power BI visuals
# * Group and bin data for analysis
# * Conduct time series analysis
# * Perform Top N analysis
# * Resume Progress

# %% [markdown]
# Analytics encompasses emerging industry practices, such as
# * data mining,
# * big data analytics,
# * machine learning,
# * AI, and
# * predictive analytics.
#
# It is a term that is used to describe the technical aspects of analytics that have predictive capabilities and can be used to solve business problems.

# %% [markdown]
# Analytics can transform raw data into an extensive collection of information that categorizes data to identify and analyze behavioral data and patterns. Organizations can use this information to analyze the current state of their operations and to predict future behavior and trends by asking **"what-if"** questions. Additionally, analytics can help with
# * fraud detection,
# * image recognition,
# * sentiment analysis,
# * overall general employee productivity, and
# * it also often replaces cumbersome manual processes.

# %% [markdown]
# Consider the scenario where we ask an employee to determine the cause of a recent spike in sales. The employee might have to
# * painstakingly inspect each sale,
# * interview customers,
# * talk to sales people, and
# * examine market trends.
#
# Instead, we can use the Microsoft Power BI key influencers visual to use advanced analytics and possibly get an answer much faster. The visual is only as good as the data that we give it, so we'll still have to collect the data and organize it. The actual analytics, however, can be done for us or at least give us an excellent start.

# %% [markdown]
# By reducing manual work, advanced analytics is ultimately able to help organizations make better business decisions and create actionable and meaningful results.
#
# Traditionally, data analysis was a complex task that was carried out by engineers. Today, data analysis is more accessible to, and understood by, many people within organizations, across all teams. Power BI is an exceptional tool for quickly pulling actionable insights from data. It allows us to build visuals and metrics for our data in reports and dashboards so that we and our users can analyze data insights at a high level and drill down into those insights for more detailed information.

# %% [markdown]
# In this lesson's scenario, we work for Tailwind Traders as a data analyst. We've been tasked with building reports and dashboards that will be used across the organization to help with crucial business decisions. For example,
# * the Product team is interested in learning if specific products are not selling as well as others,
# * the Sales team is focused on sales forecasts for the coming year, and
# * the Warehouse team is interested in a general breakdown of how the warehousing and shipping locations are performing worldwide.
#
# For each of these teams, we have to build and share unique reports and dashboards that display high-level insights and visuals that are developed by using advanced analytics.

# %% [markdown]
# The inherent functionality of Power BI will help us accomplish this task. We can develop quick insights and share them in reports and dashboards with different teams within the organization. The advanced analytics capabilities of Power BI will enable us to identify categories and trends, see how data changes over time, and much more. From this information, we can make predictive data models and, therefore, help our organization make more robust business decisions, plans, and forecasts.
#
# This two-part lesson outlines the advanced analytic capabilities of Power BI. By the end of this lesson and the next, we will be able to:
#
# * Explore statistical summary.
# * Identify outliers with Power BI visuals.
# * Group and bin data for analysis.
# * Apply clustering techniques.
# * Conduct time series analysis.
# * Use the Analyze feature.
# * Use advanced analytics custom visuals.
# * Review Quick insights.
# * Apply AI Insights.

# %% [markdown]
# Data is often intertwined with statistics because statistics are one way in which we can explore our data. Statistics show us the distribution of our data and help us to identify key takeaways and trends and determine whether outliers exist.
#
# The statistical summary is the information that provides a quick and simple description of our data. Power BI has many functions that help us to conduct a statistical analysis, such as
# * Data Analysis Expressions (DAX) functions,
# * visuals such as histograms and bell curves,
# * advanced analytics visuals, and
# * statistical programming languages such as Python and R.
#
# Exploring the statistical summary gives the user a high-level view of the available data, where they can see clusters, patterns on behavioral data, data averages, and more. They can gain insights about their data that will help drive business decisions.
#
# For example, the Supply Chain team asks us to create a report that shows the frequency of orders for certain products and what the top 10 products are in terms of sales.

# %% [markdown]
# This lesson uses real data from Dataquest. The dataset includes information about total signups and subscriptions by day to [dataquest.io](https://www.dataquest.io/). The data is aggregated by country, channel, and persona. Details about each field (column) are as follows:
#
# * **active_window_subscribers**: number subscribers during the active window (first 14 days from signup).
# * **channel**: signup source, including paid (e.g. Facebook advertizing), organic (e.g. browser search result, blog post), referral, brand, or unknown.
# * **country**: signup source by country.
# * **persona**: learner type specified during onboarding (job seeker, career builder, career explorer, other, or blank).
# * **total_active_over_one_hour**: number of signups with more than one hour of activity in the first 14 days from signup.
# * **total_active_subscribers**: number of subscribers active on the Dataquest platform in the last 30 days.
# * **total_minutes_spent**: total minutes spent active on the Dataquest platform.
# * **total_signups**: total signups aggregated by day, country, channel, and persona.
# * **total_subscribed_in_first_14days_window**: number of subscriptions in the first 14 days from signup.
# * **total_subscribers**: total signups that purchased a Dataquest subscription. Aggregated by day, country, channel, and persona.
# * **date_joined**: date of signup to [Dataquest.io](https://www.dataquest.io/).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Power BI Desktop has a number of DAX functions that we can use to get quick statistics based on our data. We can access these quick functions by right-clicking the **Values** field in the **Visualizations** pane, as illustrated in the following image.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# However, to avoid performance issues, it's better to create the statistical measures ourself by using DAX functions to calculate **average**, **sum**, **min**, **max**, and so on. For example, to analyze the inventory data to find the average order quantity for each product, we could use the following formula:
#
# `Average Qty = AVERAGE(Sales[Order Qty])`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Histograms and bell curves are the most common way to display statistics about our datasets. In Power BI terms, we can
#
# * represent a histogram with one of the bar or column chart visuals and
# * represent a bell curve with an area chart visual, as illustrated in the following image.
#
# We can also use the Q&A visual to ask a direct question about the top or bottom items in a list.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# A typical bar or column chart visual in Power BI relates two data points:
# * a measure and
# * a dimension.
#
# A histogram differs slightly from a standard bar chart in that it only visualizes a single data point.
#
# In this example, we use the clustered column chart visual to present a histogram that determines the order quantities by order sizes.
#
# * We start by selecting the clustered column chart icon on the **Visualizations** pane.
# * Next, create a new grouping for the x-axis.
#
# We will learn more about grouping and binning later in this file, but they are useful in this context also.

# %% [markdown]
# To create the group, in the **Fields** pane,
# * right-click the data field that we want to analyze and
# * then select **New Group**.
#
# In this case, we use the `OrderQty` field. In the **Groups** window that displays, set up the bin group as follows:
#
# * Rename the group as Order Bins (Buckets).
# * Set the Group type option to Bin and the Bin Type option to Number of bins.
# * Enter `5` as the Bin count, `1` as the Min value, and `44` as the Max value.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Next, populate the visual as follows:
#
# * Drag and drop the `OrderQty` field from the **Fields** pane into the **Value** field on the **Visualizations** pane.
# * Drag and drop the Order Bins (Buckets) group from the **Fields** pane into the **Axis** field on the **Visualizations** pane.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The visual now shows that the data is grouped into buckets on the x-axis, with the order quantities of that variable on the y-axis.
#
# We have now produced a histogram that displays the order quantity (`OrderQty` field) by order size buckets for the Supply Chain team.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The `TOPN` DAX function returns the top N rows of a specified table. The Top N analysis is a great way to present data that might be important, such as the
# * top 10 selling products,
# * top 10 performers in an organization, or
# * top 10 customers.
#
# Alternatively, we can look at it from the other perspective and present the bottom 10 items in a list, in other words, the worst performers. Depending on the requirements, we might want to use one or both of these options.
#
# In this example, the Supply Chain team wants to know what the top 10 selling products are. We accomplish this task in one of three ways:
# * by using a Q&A visual,
# * using a Top N filter, or
# * writing a DAX formula.

# %% [markdown]
# ### Use the Q&A visual to find the top N
#
# We've created a report for the Supply Chain team, and now the team members have questions about various other views or insights that they are interested in. Power BI has a built-in Q&A visual that allows users to ask their own questions and get answers so we don't have to address each individual question. The Q&A visual is an effective tool because it allows users to quickly get answers about the data independently, which saves time for everyone involved. The Q&A visual is unique in that it does not require knowledge of Power BI to use the visual; users can ask their question and they, too, can create insightful visuals.
#
# Add the Q&A visualization to our report, and then reposition the visual and customize its formatting, as required.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, we can use the visual to get answers. In this case, we want to know what the top 10 selling products are, so we enter a question such as, **"What are my top 10 products by sales?"** Power BI will automatically display those results for us.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Use a Top N filter type
#
# Top N is a filtering option that is available on the **Filters** pane.
# * Select the field that we want to analyze on our report page (in this example, it's the Product Name field).
# * In the **Filters** pane, expand the **Filter type** list and select Top N.
# * In the **Show items** settings, select Top and 10.
# * Then, select `Cost of Sales` as the value that we want to filter the field by. The visual updates accordingly.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Use a TOPN DAX function
#
# We can also calculate our top 10 products in DAX by using the `TOPN` function. This option could be useful if we want to present the top 10 in a different context, such as how much of the top 10 best-selling products contributed toward the overall total sales.
#
# * Start by creating a new measure called Top 10 Products.
# * Then, use the `TOPN` function, along with the `SUMX` function, to calculate our top 10 products by total sales, as follows:
#
# `Top 10 Products = SUMX(TOPN(10, Product, Product[Product Name], ASC), [Total Sales])`

# %% [markdown]
# The following image shows how much the top 10 products contribute toward the overall sales.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We can adjust the DAX formula to present the same result in percentages.
#
# For more information about the statistical capabilities of Power BI, see [Statistical Functions - DAX](https://docs.microsoft.com/en-us/dax/statistical-functions-dax).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# An outlier is a type of anomaly in our data, something that we didn't expect or that surprised us, based on historical averages or results. We will want to identify outliers to isolate data points that significantly differ from other data points, and then take action to investigate the reasons for the differences. The results of this analysis can make a significant impact on business decision making.
#
# Consider the scenario where we are analyzing data for a shipping warehouse. We notice that the number of orders increased above average for a specific product category. We first want to identify the product category. Then, we want to ask several questions about the outlier:
#
# * Did above average shipments happen that day?
# * Did this anomaly occur in a specific warehouse?
# * Did a single event cause the increase in orders for that specific category?
# * Did this event occur on other days in the last month, quarter, year, or prior year?

# %% [markdown]
# Power BI allows us to identify outliers in your data, but we need to first determine the logic behind what constitutes an outlier. We can use trigger points, such as calculations, around what we would consider the outlier to be.
#
# The process of identifying outliers involves segmenting our data into two groups:
# * one group is the outlier data and
# * the other group is not.
#
# We could use calculated columns to identify outliers, but the results would be static until we refresh the data. A better way to identify outliers is to use a visualization or DAX formula because these methods will ensure that our results are dynamic.
#
# When we have identified the outliers in our data, we can then use slicers or filters to highlight those outliers. Additionally, we can add a legend to our visuals so that the outliers can be identified among the other data. We can then drill in to the outlier data for more detailed analysis.

# %% [markdown]
# ### Use a visual to identify outliers
#
# The best visual to use for identifying outliers is the scatter chart, which shows the relationship between two numerical values. Scatter charts display patterns in large sets of data and are, therefore, ideal for displaying outliers.
#
# When we add a scatter chart to our Power BI report, we put our fields of interest in the **X Axis** and **Y Axis** sections, respectively. In this case, the `Orders Shipped` field is on the **x-axis**, and the `Qty Orders` field is on the **y-axis**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The visual will update to display the data according to the selected fields, and we'll be able to clearly identify the outliers in that data; they are the isolated items that are away from the bulk of the data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now that we can identify the outliers in our data, we can investigate the reasons for their existence and take corrective action.

# %% [markdown]
# ### Use DAX to identify outliers
#
# We can use DAX to create a measure that will identify the outliers in our data, such as in the following formula:
#
# `Outliers =
# CALCULATE (
# [Order Qty],
# FILTER (
# VALUES ( Product[Product Name] ),
# COUNTROWS ( FILTER ( Sales, [Order Qty] &#62;= [Min Qty] ) ) &#62; 0
# )
# )`

# %% [markdown]
# * When we have created a new outlier measure, we can group our products into categories by using the grouping feature, as we previously did when creating a histogram.
# * We then need to add a scatter chart visual, as we did in the previous section, because this is the best visualization option for displaying outliers.
# * When we've added the scatter chart, populate it with the fields that are associated with our DAX formula and outlier measure.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In the scatter chart, we'll be able to identify the outliers in our data. We can then investigate the reasons for their existence and take corrective action.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In 2004, Hans Rosling presented a Ted Talk titled, **"The best stats you've ever seen."** In that talk, Hans showed a video that allowed him to analyze data over time by playing an animated chart. The chart progressed, year-by-year, where viewers could watch how the longevity and family size moved over time for the entire world. This presentation initiated tremendous interest in the power of data visualization, particularly as it related to time series analysis.
#
# Time series analysis involves analyzing a series of data in time order to identify meaningful information and trends and make predictions. The result of time series analysis is the best data that we can use for forecasting activities.
#
# Time series analysis often involves the use of visuals such as
# * Gantt charts,
# * project planning, and
# * stock movement datasets.
#
# In Power BI, we can use visuals to view how our data is progressing over time, which in turn allows us to make observations, such as if any major events disrupted our data.

# %% [markdown]
# To conduct a time series analysis in Power BI, we need to use a visualization type that is suitable for displaying trends and changes over time, such as a
# * line chart,
# * area chart, or
# * scatter chart.
#
# We can also import a time series custom visual into Power BI Desktop from Microsoft AppSource. The following example uses a standard scatter chart.
#
# In addition to the range of time series custom visuals, Microsoft AppSource has an animation custom visual called **Play Axis** that works like a dynamic slicer and is a compelling way to display time trends and patterns in our data without user interaction. This visual is similar to the one that Hans Rosling used in his original presentation and is used alongside the scatter chart in the following example.
#
# **Note:** Some organizations prefer not to use custom visuals for security or other reasons. Before we import custom visuals, check with our organization to see if they are allowed or not. If they are not allowed, we can instead use the **Play Axis** visual that is available for scatter chart visualizations within Power BI Desktop because it has similar functionality.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In this example, we are developing a Sales report. The Sales team wants to study the quarterly sales trends and identify which models sell better, depending on the time of the season. We decide to use two visuals, a **scatter chart** and **line chart**, for the purpose of time series analysis, and then enhance those visuals with animation so the Sales team can see how the sales data changes over time.
#
# We start by adding our visuals to the report page to show the sales data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Next, we will import the animation custom visual to use with the visuals. In the **Visualizations** pane,
# * select the **Get more visuals** icon and
# * then select **Get more visuals**.
#
# On the Power BI **Visuals** window that displays, search for play axis, and then select the **Add** button for the **Play Axis** (Dynamic Slicer) visual.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# A message will display, stating that the visual was successfully imported. When we return to Power BI Desktop, we'll see the new **Play Axis** icon in the Visualizations pane.
# * Select the page, and then
# * select the **Play Axis** icon to add that visual to the page.
#
# With the new visual selected, select the field (Quarter) that we want to use as the slicer in the **Play Axis** animation. Animation controls become available on the visual.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We can now resize and reposition the new visual and customize its formatting so that it's consistent with the other visuals on the page. Specific formatting options that we might want to use include:
#
# * In the **Animation Settings** section, we can control the play functionality of the **Play Axis** visual, such as making the animation automatically start, continue looping, and then change the speed at which the animation occurs.
# * In the **Colors** section, we can change the appearance of the **Play Axis** visual by adjusting its overall color, or selecting the **Show all** option, and then changing the color of each control button.
# * The **Enable Caption On** section allows us to turn **on/off** the text that is displayed next to the visual or adjust the formatting of it.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When we have set up the **Play Axis** visual to meet our requirements, we are ready to use it with our other visuals. Select the **Play** button and then watch how the data in each visual on the page evolves over the time. We can use the control buttons to pause the animation, restart it, and so on.

# %%
from IPython.display import Image

Image("6-animated-play-axis-visual.gif")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Clustering allows us to identify a segment (cluster) of data that is similar to each other but dissimilar to the rest of the data. The process of clustering is different to that of grouping, which we accomplished previously.
#
# The Power BI clustering feature allows us to quickly find groups of similar data points in a subset of our data. It analyzes our dataset to identify similarities and dissimilarities in the attribute values, and then it separates the data that has similarities into a subset of the data. These subsets of data are referred to as clusters.
#
# For example, we might want to look for patterns in our sales data, such as the behavior of customers overall. We can segment the customers into clusters according to their similarities, such as age or location.

# %% [markdown]
# Start by adding the scatter chart visualization to our report and then add the required fields to the visual. In this example, we will add the `Order Qty` field to the **x-axis**, the `Sales` field to the **y-axis**, and the `Product Name` field to the Details section. The following image shows considerable data in the scatter chart, so it is difficult to discern any natural groups.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To apply clustering to our scatter chart,
# * select **More options (...)** in the upper-right corner of the visual and
# * then select **Automatically find clusters**.
#
# **Note:** The **Automatically find clusters** option is unavailable in the Power BI Desktop version we are using here.
#
# On the **Clusters** window that displays, we can edit the default name, field, and description, if required. However, for this example, we want to change the number of clusters. The following image shows that the Number of clusters box is blank by default, which means that Power BI automatically finds the number of clusters that it determines as making the most sense with our data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Enter the number of clusters that we want **(3)** into the box and then select **OK**. Power BI will run the clustering algorithm and create a new categorical field with the different cluster groups in it. Now, when we look at the visual, we can clearly see the clusters that are in our data and proceed to perform analysis on them.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The new cluster field is added to our scatter chart's Legend field well bucket, which we can now use as a source of cross-highlighting like any other Legend field. We can also find the new cluster field in our field list and use it in new visuals, just like any other field.
#
# If we want to edit the cluster, right-click the cluster field and select **Edit clusters**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In the preceding example, when we applied clustering to the scatter chart, we could only use two measures. If we want to find clusters by using more than two measures, we can use a table visual instead, add all the fields we want to use, and then run the clustering algorithm by using the same process.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When we create visuals, Power BI Desktop aggregates our data into groups, based on the values that it finds in the underlying data. We can refine how those default groups are presented. We can also create new groups by grouping two or more data points in a visual or putting values into equal-sized groups (binning).
#
# Grouping is used for categories of data. Binning is similar to grouping, but it is used for grouping continuous fields, such as numbers and dates.
#
# We can use the grouping and binning features to ensure that the visuals in our reports display our data according to our preference. Using these features will help us to clearly view, analyze, and explore the data and trends in our visuals. Additionally, we'll be able to identify clusters, patterns of behavior, data averages, and more. The results of this analysis will provide our users with more specific insights on their data, which can help drive business decisions.
#
# In this example, the Customer Service team has returned to us, greatly impressed by the analysis that we have done. Now, they want us to further analyze their Help ticket data, asking if we can segment the data into different groups and clusters. In particular, they want to identify the cities with the highest sales.

# %% [markdown]
# ### Create a group
#
# The following image shows a bar chart in which Power BI has automatically segmented the data in the way that it found most useful: Total Sales by State. However, we want to group some of the bars (states) together so that we can view them as one category, which will help the Sales team identify the cities with the highest sales.
#
# To create the group, use **Ctrl + click** to select the data points on the visual that we want to group. Alternatively, for the field of interest select the elipsis (...) in the **Fields** pane, then select **New group**. In this case, it's states with sales greater than 500,000 dollars. Right-click one of those selected data points and then select the **Group data** option.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When the group is created, notice that the visual updates to take into account the new group. The following image shows that the other states, which are the states with lower sales (less than 500,000 dollars) have been grouped together and are highlighted in a different shade.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The new group field displays in the Legend bucket for the visual and is listed in the **Fields** pane.
#
# When we create a group, we can change the way that the data is displayed in the visual. For example, we might want to switch the values in each axis. We can also use the group in any of the other visuals in our report. To do so, drag the group field from the **Fields** pane and then drop it into the visual in which we want to use it.

# %% [markdown]
# ### Edit a group
#
# Continuing with the previous example, we now want to edit the categories that make up our group. Right-click the group field in either the **Legend** bucket or the **Fields** pane, and then select **Edit Groups**.
#
# In the **Groups** window that displays is a list of the groups and the different items within those groups. The following image shows the States with Sales > 500k group and its members, along with the Other group (States with Sales < 500k) that contains all other values that have not been put into the first group. If we refresh our data, and new items appear in the ungrouped values list, they'll all go into the Other group.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We can now make changes to the group. We can rename any group by double-clicking the group title in the **Groups and members** section and entering a new name. We can add ungrouped values into an existing group, remove values from an existing group, and create a new group.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Create bin groups
#
# The process of binning allows us to group our numerical and time field data into "bins" of equal size. This approach allows us to visualize and identify trends in our data in more meaningful ways. Binning allows us to right-size the data that Power BI Desktop displays.
#
# In this example, we want to create bins (groups) for the Order Qty field. Start in the **Fields** pane by right-clicking the `Order Qty` field that we want to create the bins for, and then select **New Group**. On the **Groups** window that displays, set the **Bin size** to the size that we want, adjust other settings as required, and then select **OK**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When we have set up the bin group, we'll see a new field in the **Fields** pane with (bins) appended to its name. We can then drag that field onto the canvas to use the bin size in a visual.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In this file, we learned about the emerging power of advanced analytics and discovered how the advanced analytics capabilities of Power BI can bring value to our organization's decision making and strategy formulation.
#
# We enhanced the reports and dashboard that we previously created to enable users across our organization to ask more questions and find more information that is specific to their teams and work contexts. We used Power BI to explore our data and create a statistical summary to find key takeaways and trends and identify outliers that might require immediate action. We conducted a time series analysis of our data to see how our data progressed over time so that we could make observations and forecast behavior.
#
# The advanced analytical techniques that we applied to our organization's data enabled us to gain new insights in that data, and further scrutinize the data to uncover patterns, trends, and outliers that we did not know existed. The results of our advanced analysis will empower our organization to make more robust business decisions, plans, and forecasts.
